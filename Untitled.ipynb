# %%
import pandas as pd
import numpy as np
import seaborn as sns
import math
from numpy.random import randint

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# survived       891 non-null int64
# pclass         891 non-null int64
# sex            891 non-null object
# age            714 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# fare           891 non-null float64
# embarked       889 non-null object
# class          891 non-null category
# who            891 non-null object
# adult_male     891 non-null bool
# deck           203 non-null category
# embark_town    889 non-null object
# alive          891 non-null object
# alone          891 non-null bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
a = len(df.columns.values)
dfList = []
for i,j,k in zip(df.columns.values, df.dtypes, df.isna().sum() ):
    dfList.append([i,j,k,(k/len(df.isna())*100),df[i].nunique(),df[i].sample().unique()[0]]);
dfP = pd.DataFrame(columns=['dataFeatures','dataType','null','nullPct','unique','uniqueSample'],
                    data=dfList)
dfP
# for item in df.columns.values:
#     print(df[item].sample().unique())
# Out:
#    dataFeatures  dataType  null    nullPct  unique uniqueSample
# 0      survived     int64     0   0.000000       2            1
# 1        pclass     int64     0   0.000000       3            3
# 2           sex    object     0   0.000000       2       female
# 3           age   float64   177  19.865320      88           35
# 4         sibsp     int64     0   0.000000       7            0
# 5         parch     int64     0   0.000000       7            2
# 6          fare   float64     0   0.000000     248         8.05
# 7      embarked    object     2   0.224467       3            S
# 8         class  category     0   0.000000       3        Third
# 9           who    object     0   0.000000       3          man
# 10   adult_male      bool     0   0.000000       2         True
# 11         deck  category   688  77.216611       7          NaN
# 12  embark_town    object     2   0.224467       3  Southampton
# 13        alive    object     0   0.000000       2           no
# ...

# %%
df.columns.values
# Out:
# array(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'], dtype=object)

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
for item in df.columns.values:
    print(df[item].sample().unique())
# Out:
# [0]
# [1]
# ['male']
# [36.]
# [0]
# [0]
# [7.2292]
# ['S']
# [Second]
# Categories (1, object): [Second]
# ['man']
# [ True]
# [NaN]
# Categories (0, object): []
# ['Southampton']
# ['no']
# [ True]

# %%
df.isna().sum()/len(df.isna())*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
df.groupby('sex').mean()
# Out:
#         survived    pclass        age     sibsp     parch       fare  \
# sex
# female  0.742038  2.159236  27.915709  0.694268  0.649682  44.479818
# male    0.188908  2.389948  30.726645  0.429809  0.235702  25.523893
#
#         adult_male     alone
# sex
# female    0.000000  0.401274
# male      0.930676  0.712305

# %%
df.groupby('sex').describe().transpose()
# Out:
# sex                 female        male
# age      count  261.000000  453.000000
#          mean    27.915709   30.726645
#          std     14.110146   14.678201
#          min      0.750000    0.420000
#          25%     18.000000   21.000000
#          50%     27.000000   29.000000
#          75%     37.000000   39.000000
#          max     63.000000   80.000000
# fare     count  314.000000  577.000000
#          mean    44.479818   25.523893
#          std     57.997698   43.138263
#          min      6.750000    0.000000
#          25%     12.071875    7.895800
#          50%     23.000000   10.500000
#          75%     55.000000   26.550000
#          max    512.329200  512.329200
# parch    count  314.000000  577.000000
#          mean     0.649682    0.235702
#          std      1.022846    0.612294
#          min      0.000000    0.000000
#          25%      0.000000    0.000000
#          50%      0.000000    0.000000
#          75%      1.000000    0.000000
# ...

# %%
print('Jumlah Data : ' + str(len(df[df['class']!='Second'])))
print('Mean Umur Pria : ' + str(df[(df['sex']=='male') & (df['class']!='Second')]['age'].mean()))
df[df['class']!='Second'][['sex','age']].head()
# len(df[df['class']!="Second"])
# df[(df['sex']=='male') & (df['class']!='Second')]['age'].mean()
# Out:
# Jumlah Data : 707
# Mean Umur Pria : 30.72271186440678
#       sex   age
# 0    male  22.0
# 1  female  38.0
# 2  female  26.0
# 3  female  35.0
# 4    male  35.0

# %%
df[(df['class']=='Second') & (df['alone']==True)]['fare'].sum()
# Out:
# 1462.875

# %%
print('Banyak NaN man & mean : ' + str(df[df['who']=='man']['age'].isna().sum()) + " & " + str(df[df['who']=="man"]['age'].mean()))
print('Banyak NaN woman & mean : ' + str(df[df['who']=='woman']['age'].isna().sum()) + ' & ' + str(df[df['who']=="woman"]['age'].mean()))
print('Banyak NaN child & mean : ' + str(df[df['who']=='child']['age'].isna().sum()) + ' & '+ str(df[df['who']=="child"]['age'].mean()))
# Out:
# Banyak NaN man & mean : 124 & 33.17312348668281
# Banyak NaN woman & mean : 53 & 32.0
# Banyak NaN child & mean : 0 & 6.369518072289157

# %%
df[df['who']=="man"]['age'].mean()
# Out:
# 33.17312348668281

# %%
(df[df['who']=="man"]['age'].isna().sum())
# Out:
# 124

# %%
df[df['who']=='woman']['age'].mean()
# Out:
# 32.0

# %%
df[df['who']=='woman']['age'].isna().sum()
# Out:
# 53

# %%
b = df[df['who']=='woman']['age'].mean()
df[df.loc[:,'who']=='woman'].loc[:,'age'].fillna(b, inplace=True)
df[df['who']=='woman']
# Out:
# C:\Users\Rizqa\Anaconda3\lib\site-packages\pandas\core\generic.py:5430: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 2           1       3  female  26.0      0      0    7.9250        S   Third
# 3           1       1  female  35.0      1      0   53.1000        S   First
# 8           1       3  female  27.0      0      2   11.1333        S   Third
# 11          1       1  female  58.0      0      0   26.5500        S   First
# 15          1       2  female  55.0      0      0   16.0000        S  Second
# 18          0       3  female  31.0      1      0   18.0000        S   Third
# ...

# %%
df[df['who']=='child']['age'].mean()
# Out:
# 6.369518072289157

# %%
df[df['who']=='child']['age'].isna().sum()
# Out:
# 0

# %%
a = df[df['who']=="man"]['age'].mean()
print(float(a))
# df[df['who']=='man'] = df[df['who']=='man'].fillna(a)
df[df['who']=='man']['age'].fillna(float(a), inplace=True)
df[df['who']=='man']
# Out:
# 33.17312348668281
# C:\Users\Rizqa\Anaconda3\lib\site-packages\pandas\core\generic.py:5430: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
#      survived  pclass   sex   age  sibsp  parch      fare embarked   class  \
# 0           0       3  male  22.0      1      0    7.2500        S   Third
# 4           0       3  male  35.0      0      0    8.0500        S   Third
# 5           0       3  male   NaN      0      0    8.4583        Q   Third
# 6           0       1  male  54.0      0      0   51.8625        S   First
# 12          0       3  male  20.0      0      0    8.0500        S   Third
# 13          0       3  male  39.0      1      5   31.2750        S   Third
# 17          1       2  male   NaN      0      0   13.0000        S  Second
# ...

# %%
df['embarked'].fillna(df['embarked'].mode()[0], inplace=True)
print("Modus Embarked : " + df['embarked'].mode()[0])
print(df['embarked'].isna().sum())
# Out:
# Modus Embarked : S
# 0

# %%
df['embark_town'].fillna(df['embark_town'].mode()[0], inplace=True)
print("Modus embark_town : " + df['embark_town'].mode()[0])
print(df['embark_town'].isna().sum())
# Out:
# Modus embark_town : Southampton
# 0

# %%
df['deck'].fillna(df['deck'].mode()[0], inplace=True)
print("Modus Deck : " + df['deck'].mode()[0])
print(df['deck'].isna().sum())
# Out:
# Modus Deck : C
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# survived       891 non-null int64
# pclass         891 non-null int64
# sex            891 non-null object
# age            714 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# fare           891 non-null float64
# embarked       891 non-null object
# class          891 non-null category
# who            891 non-null object
# adult_male     891 non-null bool
# deck           891 non-null category
# embark_town    891 non-null object
# alive          891 non-null object
# alone          891 non-null bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %%
# df['age'].replace(df[(df['who']=='man') & (df['age'].isnull())]['age'], df['age'].mean)
df[df['who']=='man']['age'].mean()
df['age'] = df['age'].replace(df[(df['who']=='man') & (df['age'].isna())]['age'], df[df['who']=='man']['age'].mean())
df['age'] = df['age'].replace(df[(df['who']=='woman') & (df['age'].isna())]['age'], df[df['who']=='woman']['age'].mean())
# df['age'] = df['age'].replace(df[(df['who']=='man') & (df['age'].isnull())]['age'], df['age'].mean)
df
# Out:
#      survived  pclass     sex        age  sibsp  parch      fare embarked  \
# 0           0       3    male  22.000000      1      0    7.2500        S
# 1           1       1  female  38.000000      1      0   71.2833        C
# 2           1       3  female  26.000000      0      0    7.9250        S
# 3           1       1  female  35.000000      1      0   53.1000        S
# 4           0       3    male  35.000000      0      0    8.0500        S
# 5           0       3    male  33.173123      0      0    8.4583        Q
# 6           0       1    male  54.000000      0      0   51.8625        S
# 7           0       3    male   2.000000      3      1   21.0750        S
# 8           1       3  female  27.000000      0      2   11.1333        S
# 9           1       2  female  14.000000      1      0   30.0708        C
# 10          1       3  female   4.000000      1      1   16.7000        S
# 11          1       1  female  58.000000      0      0   26.5500        S
# ...

# %%
q = df.groupby('class')['fare'].mean()

# %%
r = df.groupby('class')['fare'].std()

# %%
df.groupby('class')['fare'].mean() - df.groupby('class')['fare'].std()
# Out:
# class
# First     5.774315
# Second    7.244784
# Third     1.897408
# Name: fare, dtype: float64

# %%
df.groupby('class')['fare'].mean() + df.groupby('class')['fare'].std()
# Out:
# class
# First     162.535060
# Second     34.079582
# Third      25.453692
# Name: fare, dtype: float64

# %%
s = df.groupby('class')['fare'].mean() - 3*df.groupby('class')['fare'].std()

# %%
t = df.groupby('class')['fare'].mean() + 3*df.groupby('class')['fare'].std()

# %%
# print(q,r,s,t)
fareList =[]
for i in df['class'].unique():
    fareList.append([i, df[df['class']==i]['fare'].mean(),df[df['class']==i]['fare'].std(),df[df['class']==i]['fare'].mean() - (3*df[df['class']==i]['fare'].std()),df[df['class']==i]['fare'].mean() + (3*df[df['class']==i]['fare'].std())])
dfF = pd.DataFrame(columns=['id','mean_fare','std_fare','batas-min-fare','batas-max-fare'],
                    data=fareList)
d = {'Third':1,'First':2, 'Second':3}
# dfF = dfF.replace(d)
dfF
# Out:
#        id  mean_fare   std_fare  batas-min-fare  batas-max-fare
# 0   Third  13.675550  11.778142      -21.658875       49.009975
# 1   First  84.154687  78.380373     -150.986430      319.295805
# 2  Second  20.662183  13.417399      -19.590013       60.914379

# %%
dfF['id']
# Out:
# 0     Third
# 1     First
# 2    Second
# Name: id, dtype: object

# %%
df['class'].unique()
# Out:
# [Third, First, Second]
# Categories (3, object): [Third, First, Second]

# %%
df[df['class']=='First']['fare'].mean()
# Out:
# 84.15468749999992

# %%
(3*df.groupby('class')['fare'].std())/df.groupby('class')['fare'].mean()
# Out:
# class
# First     2.794154
# Second    1.948110
# Third     2.583766
# Name: fare, dtype: float64

# %%
df.groupby('class')['fare'].describe()
# Out:
#         count       mean        std  min       25%      50%   75%       max
# class
# First   216.0  84.154687  78.380373  0.0  30.92395  60.2875  93.5  512.3292
# Second  184.0  20.662183  13.417399  0.0  13.00000  14.2500  26.0   73.5000
# Third   491.0  13.675550  11.778142  0.0   7.75000   8.0500  15.5   69.5500

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True    C  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False    C  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True    C  Southampton    no   True

# %%
(df[df['class']=='First']['fare'].mean() + df[df['class']=='First']['fare'].std()) / df[df['class']=='First']['fare'].mean()
# Out:
# 1.931384513152983

# %%
df.groupby('class')['fare'].mean() - df.groupby('class')['fare'].std()
# Out:
# class
# First     5.774315
# Second    7.244784
# Third     1.897408
# Name: fare, dtype: float64

# %%
(dfF['batas-min-fare']/dfF['batas-max-fare'])
# Out:
# 0   -0.441928
# 1   -0.472873
# 2   -0.321599
# dtype: float64

# %%
df.groupby('class').count()
# Out:
#         survived  pclass  sex  age  sibsp  parch  fare  embarked  who  \
# class
# First        216     216  216  216    216    216   216       216  216
# Second       184     184  184  184    184    184   184       184  184
# Third        491     491  491  491    491    491   491       491  491
#
#         adult_male  deck  embark_town  alive  alone  outliercalcid
# class
# First          216   216          216    216    216            216
# Second         184   184          184    184    184            184
# Third          491   491          491    491    491            491

# %%
7.75 - (7.75)*1.5

# %%
7.75/-3.875

# %%
df['fare'].describe()

# %%
(df['fare'].describe()['75%']-df['fare'].describe()['25%'])

# %%
df['fare'].describe()['25%'] - 1.5*(df['fare'].describe()['75%']-df['fare'].describe()['25%'])

# %%
df['fare'].describe()['25%'] + 1.5*(df['fare'].describe()['75%']-df['fare'].describe()['25%'])

# %%
def outliers_iqr(ys):
    quartile_1, quartile_3 = np.percentile(ys, [25, 75])
    iqr = quartile_3 - quartile_1
    lower_bound = quartile_1 - (iqr * 1.5)
    upper_bound = quartile_3 + (iqr * 1.5)
    return np.where((ys > upper_bound) | (ys < lower_bound))

# dfQ = list(map(outliers_iqr, df['fare']))
df

# %%
def outlier_cetak(kelas):
    if kelas=='Third':
        return '1'
    elif kelas == 'First':
        return '2'
    elif kelas == 'Second':
        return '3'
    
df['outliercalcid'] = list(map(outlier_cetak,df['class']))
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone outliercalcid
# 0    man        True    C  Southampton    no  False             1
# 1  woman       False    C    Cherbourg   yes  False             2
# 2  woman       False    C  Southampton   yes   True             1
# 3  woman       False    C  Southampton   yes  False             2
# 4    man        True    C  Southampton    no   True             1

# %%
df[np.abs(df['fare']-df['fare'].mean()) <= (3*df['fare'].std())]
df.head()
